# %%
import cv2
import matplotlib.pyplot as plt

# %%
img = cv2.imread(r"C:\Users\CC\Desktop\VS Code\college training\image processing\ChatGPT Image Apr 28, 2025, 09_54_53 PM.png")
# cv2.imshow("image",img)
# cv2.waitKey(0)
# cv2.destroyAllWindows()
plt.imshow(img)
plt.show()

# %%
from PIL import Image
img1 = Image.open(r"C:\Users\CC\Desktop\VS Code\college training\image processing\ChatGPT Image Apr 28, 2025, 09_54_53 PM.png")
# img1.show()
# img1.save("sumit.png")
print(img.shape)#height width channel
print(img.size)##total number of pixel
print(img.dtype)##image data type
# Out:
# (1024, 1024, 3)
# 3145728
# uint8

# %%
## scaling changes the size of an image either enlarging or shrinking
## scaled - cv2.resize(img,(new_width,new_height))
scaled_image = cv2.resize(img,(0,0),fx = 0.5,fy = 0.5)
plt.imshow(scaled_image)

# %%
## translation changes the location of an image on the screnn

import numpy as np
rows , cols = img.shape[0:2]
tx , ty = 1000,500
M = np.float32([[1,0,tx],[0,1,ty]])
translated_image = cv2.warpAffine(img,M,(cols,rows))
plt.imshow(translated_image)

# %%
center = (cols//2,rows//2)
angle = 45
scale = 0.5
M = cv2.getRotationMatrix2D(center,angle,scale)
rotated_image = cv2.warpAffine(img,M,(cols,rows))
plt.imshow(rotated_image)

# %%
flip_image = cv2.flip(img,0)
plt.imshow(flip_image)

# %%
crooped_image = img[100:200,200:300]
plt.imshow(crooped_image)

# %%
img2 = cv2.imread(r"C:\Users\CC\Desktop\VS Code\college training\image processing\Screenshot 2025-05-30 195350.png")
gray = cv2.cvtColor(img2,cv2.COLOR_BGR2GRAY)

plt.subplot(1,2,1)
plt.imshow(img2)
plt.title("Original image")
plt.subplot(1,2,2)
plt.title("gray scale")
plt.imshow(gray,cmap="gray")
plt.show()

# %%
color = ("b","g","r")
for i, col in enumerate(color):
    plt.subplot(1,3,i+1)
    hist = cv2.calcHist([img2],[i],None,[256],[0,256])
    plt.plot(hist,color=col)
    plt.xlim([0,256])
plt.show()
