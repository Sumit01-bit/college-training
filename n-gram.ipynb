# %%
##food  good
##food not good

## vocab -- {food good, not good , good not}
##1 -- unigram
##2 -- bigram
##3 -- trigram

# %%
from sklearn.feature_extraction.text import CountVectorizer

# %%
text = ["this movie was not good"]
cv = CountVectorizer(ngram_range=(1,2))
cv.fit_transform(text)
print(cv.vocabulary_)
print(cv.get_feature_names_out())
# Out:
# {'this': 5, 'movie': 1, 'was': 7, 'not': 3, 'good': 0, 'this movie': 6, 'movie was': 2, 'was not': 8, 'not good': 4}
# ['good' 'movie' 'movie was' 'not' 'not good' 'this' 'this movie' 'was'
#  'was not']
